# %% [markdown]
# # Arrays and DataFrame
#
# ## Due Tuesday,June 16
#
#
#
# First, set up imports by running the cell below.

# %% [markdown]
# ### shubham patil ML 12

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Arrays
#
# As data scientists, we'll often be working with millions or even billions of numbers. For this, we need something faster than a `list`. Instead of lists, we will use *arrays*.
#
# Arrays are provided by a package called [NumPy](http://www.numpy.org/) .  The package is called `numpy`, but it's standard to rename it `np` for brevity.  You can do that with:
#
#     import numpy as np

# %%
import numpy as np

# %% [markdown]
# **Question 1.1** Use `np.arange` to create an array with the multiples of 99 from 0 up to (**and including**) 9999.  (So its elements are 0, 99, 198, 297, etc.)

# %%
#your Code
mult = np.arange(0,10000,99)
mult
# Out:
# array([   0,   99,  198,  297,  396,  495,  594,  693,  792,  891,  990,
#        1089, 1188, 1287, 1386, 1485, 1584, 1683, 1782, 1881, 1980, 2079,
#        2178, 2277, 2376, 2475, 2574, 2673, 2772, 2871, 2970, 3069, 3168,
#        3267, 3366, 3465, 3564, 3663, 3762, 3861, 3960, 4059, 4158, 4257,
#        4356, 4455, 4554, 4653, 4752, 4851, 4950, 5049, 5148, 5247, 5346,
#        5445, 5544, 5643, 5742, 5841, 5940, 6039, 6138, 6237, 6336, 6435,
#        6534, 6633, 6732, 6831, 6930, 7029, 7128, 7227, 7326, 7425, 7524,
#        7623, 7722, 7821, 7920, 8019, 8118, 8217, 8316, 8415, 8514, 8613,
#        8712, 8811, 8910, 9009, 9108, 9207, 9306, 9405, 9504, 9603, 9702,
#        9801, 9900, 9999])

# %% [markdown]
# **Question 1.2.** Create an array of the time, in seconds, since the start of the month at which each hourly reading was taken. Name it collection_times.
#
# Hint 1: There were 31 days in December, which is equivalent to (31×24
# ) hours or (31×24×60×60) seconds. So your array should have 31×24
#
# elements in it.
#
# Hint 2: The len function works on arrays, too. check its length and make sure it has 31×24
# elements.

# %%
#your code
collection_times = np.arange(0,31*24*60*60,60*60).reshape(24,31).T
print(collection_times)
print("The shape is :",collection_times.shape)
# Out:
# [[      0  111600  223200  334800  446400  558000  669600  781200  892800
#   1004400 1116000 1227600 1339200 1450800 1562400 1674000 1785600 1897200
#   2008800 2120400 2232000 2343600 2455200 2566800]
#  [   3600  115200  226800  338400  450000  561600  673200  784800  896400
#   1008000 1119600 1231200 1342800 1454400 1566000 1677600 1789200 1900800
#   2012400 2124000 2235600 2347200 2458800 2570400]
#  [   7200  118800  230400  342000  453600  565200  676800  788400  900000
#   1011600 1123200 1234800 1346400 1458000 1569600 1681200 1792800 1904400
#   2016000 2127600 2239200 2350800 2462400 2574000]
#  [  10800  122400  234000  345600  457200  568800  680400  792000  903600
#   1015200 1126800 1238400 1350000 1461600 1573200 1684800 1796400 1908000
#   2019600 2131200 2242800 2354400 2466000 2577600]
#  [  14400  126000  237600  349200  460800  572400  684000  795600  907200
#   1018800 1130400 1242000 1353600 1465200 1576800 1688400 1800000 1911600
#   2023200 2134800 2246400 2358000 2469600 2581200]
#  [  18000  129600  241200  352800  464400  576000  687600  799200  910800
#   1022400 1134000 1245600 1357200 1468800 1580400 1692000 1803600 1915200
#   2026800 2138400 2250000 2361600 2473200 2584800]
#  [  21600  133200  244800  356400  468000  579600  691200  802800  914400
#   1026000 1137600 1249200 1360800 1472400 1584000 1695600 1807200 1918800
#   2030400 2142000 2253600 2365200 2476800 2588400]
#  [  25200  136800  248400  360000  471600  583200  694800  806400  918000
#   1029600 1141200 1252800 1364400 1476000 1587600 1699200 1810800 1922400
#   2034000 2145600 2257200 2368800 2480400 2592000]
#  [  28800  140400  252000  363600  475200  586800  698400  810000  921600
#   1033200 1144800 1256400 1368000 1479600 1591200 1702800 1814400 1926000
#   2037600 2149200 2260800 2372400 2484000 2595600]
#  [  32400  144000  255600  367200  478800  590400  702000  813600  925200
#   1036800 1148400 1260000 1371600 1483200 1594800 1706400 1818000 1929600
#   2041200 2152800 2264400 2376000 2487600 2599200]
#  [  36000  147600  259200  370800  482400  594000  705600  817200  928800
#   1040400 1152000 1263600 1375200 1486800 1598400 1710000 1821600 1933200
#   2044800 2156400 2268000 2379600 2491200 2602800]
#  [  39600  151200  262800  374400  486000  597600  709200  820800  932400
#   1044000 1155600 1267200 1378800 1490400 1602000 1713600 1825200 1936800
#   2048400 2160000 2271600 2383200 2494800 2606400]
#  [  43200  154800  266400  378000  489600  601200  712800  824400  936000
#   1047600 1159200 1270800 1382400 1494000 1605600 1717200 1828800 1940400
#   2052000 2163600 2275200 2386800 2498400 2610000]
#  [  46800  158400  270000  381600  493200  604800  716400  828000  939600
#   1051200 1162800 1274400 1386000 1497600 1609200 1720800 1832400 1944000
#   2055600 2167200 2278800 2390400 2502000 2613600]
#  [  50400  162000  273600  385200  496800  608400  720000  831600  943200
#   1054800 1166400 1278000 1389600 1501200 1612800 1724400 1836000 1947600
#   2059200 2170800 2282400 2394000 2505600 2617200]
#  [  54000  165600  277200  388800  500400  612000  723600  835200  946800
#   1058400 1170000 1281600 1393200 1504800 1616400 1728000 1839600 1951200
#   2062800 2174400 2286000 2397600 2509200 2620800]
#  [  57600  169200  280800  392400  504000  615600  727200  838800  950400
#   1062000 1173600 1285200 1396800 1508400 1620000 1731600 1843200 1954800
#   2066400 2178000 2289600 2401200 2512800 2624400]
#  [  61200  172800  284400  396000  507600  619200  730800  842400  954000
#   1065600 1177200 1288800 1400400 1512000 1623600 1735200 1846800 1958400
#   2070000 2181600 2293200 2404800 2516400 2628000]
#  [  64800  176400  288000  399600  511200  622800  734400  846000  957600
#   1069200 1180800 1292400 1404000 1515600 1627200 1738800 1850400 1962000
#   2073600 2185200 2296800 2408400 2520000 2631600]
#  [  68400  180000  291600  403200  514800  626400  738000  849600  961200
#   1072800 1184400 1296000 1407600 1519200 1630800 1742400 1854000 1965600
#   2077200 2188800 2300400 2412000 2523600 2635200]
#  [  72000  183600  295200  406800  518400  630000  741600  853200  964800
#   1076400 1188000 1299600 1411200 1522800 1634400 1746000 1857600 1969200
#   2080800 2192400 2304000 2415600 2527200 2638800]
#  [  75600  187200  298800  410400  522000  633600  745200  856800  968400
#   1080000 1191600 1303200 1414800 1526400 1638000 1749600 1861200 1972800
#   2084400 2196000 2307600 2419200 2530800 2642400]
#  [  79200  190800  302400  414000  525600  637200  748800  860400  972000
#   1083600 1195200 1306800 1418400 1530000 1641600 1753200 1864800 1976400
#   2088000 2199600 2311200 2422800 2534400 2646000]
#  [  82800  194400  306000  417600  529200  640800  752400  864000  975600
#   1087200 1198800 1310400 1422000 1533600 1645200 1756800 1868400 1980000
#   2091600 2203200 2314800 2426400 2538000 2649600]
#  [  86400  198000  309600  421200  532800  644400  756000  867600  979200
#   1090800 1202400 1314000 1425600 1537200 1648800 1760400 1872000 1983600
#   2095200 2206800 2318400 2430000 2541600 2653200]
#  [  90000  201600  313200  424800  536400  648000  759600  871200  982800
#   1094400 1206000 1317600 1429200 1540800 1652400 1764000 1875600 1987200
#   2098800 2210400 2322000 2433600 2545200 2656800]
#  [  93600  205200  316800  428400  540000  651600  763200  874800  986400
#   1098000 1209600 1321200 1432800 1544400 1656000 1767600 1879200 1990800
#   2102400 2214000 2325600 2437200 2548800 2660400]
#  [  97200  208800  320400  432000  543600  655200  766800  878400  990000
#   1101600 1213200 1324800 1436400 1548000 1659600 1771200 1882800 1994400
#   2106000 2217600 2329200 2440800 2552400 2664000]
#  [ 100800  212400  324000  435600  547200  658800  770400  882000  993600
#   1105200 1216800 1328400 1440000 1551600 1663200 1774800 1886400 1998000
#   2109600 2221200 2332800 2444400 2556000 2667600]
#  [ 104400  216000  327600  439200  550800  662400  774000  885600  997200
#   1108800 1220400 1332000 1443600 1555200 1666800 1778400 1890000 2001600
#   2113200 2224800 2336400 2448000 2559600 2671200]
#  [ 108000  219600  331200  442800  554400  666000  777600  889200 1000800
#   1112400 1224000 1335600 1447200 1558800 1670400 1782000 1893600 2005200
#   2116800 2228400 2340000 2451600 2563200 2674800]]
# The shape is : (31, 24)

# %% [markdown]
# **Question 1.3** The powers of 2 ($2^0 = 1$, $2^1 = 2$, $2^2 = 4$, etc) arise frequently in computer science.  (For example, you may have noticed that storage on smartphones or USBs come in powers of 2, like 16 GB, 32 GB, or 64 GB.)  Use `np.arange` and the exponentiation operator `**` to compute the first 30 powers of 2, starting from `2^0`.
#
# *Hint*: Did your kernel "die" when you ran your solution? There is a common incorrect response to this problem that tries to create an array with so many entries that Python gives up. If this happens to you, double-check your answer!
#
# **Expected Output**
# ![image.png](attachment:image.png)

# %%
#your code Here
power_of_array = 2**np.arange(30)
power_of_array
# Out:
# array([        1,         2,         4,         8,        16,        32,
#               64,       128,       256,       512,      1024,      2048,
#             4096,      8192,     16384,     32768,     65536,    131072,
#           262144,    524288,   1048576,   2097152,   4194304,   8388608,
#         16777216,  33554432,  67108864, 134217728, 268435456, 536870912],
#       dtype=int32)

# %% [markdown]
# **Question 1.4** Get all items between 5 and 10 from a.
#
# Input:
#
# a = np.array([2, 6, 1, 9, 10, 3, 27])
# <br>
# <br>
# Desired Output:
#
# (array([6, 9, 10]),)

# %%
#your code here
a = np.array([2, 6, 1, 9, 10, 3, 27])
desired = a[a<=10]
desired[desired>=5]
# Out:
# array([ 6,  9, 10])

# %% [markdown]
# **Question 1.5** Create the following pattern without hardcoding. Use only numpy functions and the below input array a.
#
# Input:
#
# a = np.array([1,2,3])`
#
# Desired Output:
#
# array([1, 1, 1, 2, 2, 2, 3, 3, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3])
# <br>
# <br>
# Hint:You may use numpy repeat,tile

# %%
#your code here
a = np.array([1,2,3])
out1 =np.repeat(a,3)
out2 = np.tile(a,3)
output = np.concatenate((out1,out2))
output
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 3, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3])

# %% [markdown]
# # 2. Pandas DataFrames

# %% [markdown]
# For a collection of things in the world, an array is useful for describing a single attribute of each thing. For example, among the collection of Indian States, an array could describe the land area of each. Dataframes extend this idea by describing multiple attributes for each element of a collection.
#
# In most data science applications, we have data about many entities, but we also have several kinds of data about each entity.

# %% [markdown]
# **Question 2.1** In the cell below, we've created 2 arrays. Using the steps above, assign `top_10_movies` to a DataFrame that has two columns called "Rating" and "Name", which hold `top_10_movie_ratings` and `top_10_movie_names` respectively.
#
# **Expected Output**
# ![image.png](attachment:image.png)

# %%
top_10_movie_ratings = np.array([9.2, 9.2, 9., 8.9, 8.9, 8.9, 8.9, 8.9, 8.9, 8.8])
top_10_movie_names = np.array([
        'The Shawshank Redemption (1994)',
        'The Godfather (1972)',
        'The Godfather: Part II (1974)',
        'Pulp Fiction (1994)',
        "Schindler's List (1993)",
        'The Lord of the Rings: The Return of the King (2003)',
        '12 Angry Men (1957)',
        'The Dark Knight (2008)',
        'Il buono, il brutto, il cattivo (1966)',
        'The Lord of the Rings: The Fellowship of the Ring (2001)'
])

# %%
#your Code
top_10_movies = pd.DataFrame({'Rating':top_10_movie_ratings,'Name':top_10_movie_names})
top_10_movies
# Out:
#    Rating                                               Name
# 0     9.2                    The Shawshank Redemption (1994)
# 1     9.2                               The Godfather (1972)
# 2     9.0                      The Godfather: Part II (1974)
# 3     8.9                                Pulp Fiction (1994)
# 4     8.9                            Schindler's List (1993)
# 5     8.9  The Lord of the Rings: The Return of the King ...
# 6     8.9                                12 Angry Men (1957)
# 7     8.9                             The Dark Knight (2008)
# 8     8.9             Il buono, il brutto, il cattivo (1966)
# 9     8.8  The Lord of the Rings: The Fellowship of the R...

# %%
my_ranking = [8, 2, 1, 9, 7, 10, 6, 4, 3, 5]

# %% [markdown]
# **Question 2.2**  Create a new DataFrame called `with_ranking` by adding a column named "Ranking" to the table in `top_10_movies`.

# %%
#your code here
# with_ranking = pd.merge(top_10_movies,my_ranking)
top_10_movies['Ranking'] = my_ranking
with_ranking = top_10_movies
with_ranking
# Out:
#    Rating                                               Name  Ranking
# 0     9.2                    The Shawshank Redemption (1994)        8
# 1     9.2                               The Godfather (1972)        2
# 2     9.0                      The Godfather: Part II (1974)        1
# 3     8.9                                Pulp Fiction (1994)        9
# 4     8.9                            Schindler's List (1993)        7
# 5     8.9  The Lord of the Rings: The Return of the King ...       10
# 6     8.9                                12 Angry Men (1957)        6
# 7     8.9                             The Dark Knight (2008)        4
# 8     8.9             Il buono, il brutto, il cattivo (1966)        3
# 9     8.8  The Lord of the Rings: The Fellowship of the R...        5

# %% [markdown]
# ##  Functions and CEO Incomes
#
# Let's start with a real data analysis task.  We'll look at the 2015 compensation of CEOs at the 100 largest companies in California.  The data were compiled for a Los Angeles Times analysis [here](http://spreadsheets.latimes.com/california-ceo-compensation/), and ultimately came from [filings](https://www.sec.gov/answers/proxyhtf.htm) mandated by the SEC from all publicly-traded companies.  Two companies have two CEOs, so there are 102 CEOs in the dataset.

# %%
raw_compensation = pd.read_csv('raw_compensation.csv').set_index('Rank')
raw_compensation
# Out:
#                     Name                 Company (Headquarters) Total Pay  \
# Rank
# 1          Mark V. Hurd*                  Oracle (Redwood City)   $53.25
# 2         Safra A. Catz*                  Oracle (Redwood City)   $53.24
# 3         Robert A. Iger                  Walt Disney (Burbank)   $44.91
# 4       Marissa A. Mayer                     Yahoo! (Sunnyvale)   $35.98
# 5           Marc Benioff         salesforce.com (San Francisco)   $33.36
# ...                  ...                                    ...       ...
# 98    Gregory N. Roberts  A-Mark Precious Metals (Santa Monica)    $0.94
# 99       Jose L. Laparte                 PriceSmart (San Diego)    $0.81
# 100          Jack Dorsey                Twitter (San Francisco)    $0.07
# 101         Elon R. Musk               Tesla Motors (Palo Alto)    $0.04
# 102     Lawrence Page***               Alphabet (Mountain View)    $0.00
#
#      % Change Cash Pay Equity Pay Other Pay  \
# Rank
# 1         NaN   $0.95     $52.27     $0.02
# 2         NaN   $0.95     $52.27     $0.02
# 3         -3%  $24.89     $17.28     $2.74
# 4        -15%   $1.00     $34.43     $0.55
# 5        -16%   $4.65     $27.26     $1.45
# ...       ...      ...        ...       ...
# 98       -11%   $0.93      $0.00     $0.02
# 99        -7%   $0.71      $0.00     $0.10
# 100       NaN   $0.00      $0.00     $0.07
# 101        6%   $0.04      $0.00     $0.00
# 102        0%   $0.00      $0.00     $0.00
#
#       Ratio of CEO pay to average industry worker pay
# Rank
# 1                                           362.00000
# 2                                           362.00000
# 3                                           477.00000
# 4                                           342.00000
# 5                                           338.00000
# ...                                               ...
# 98                                           17.00000
# 99                                           32.00000
# 100                                           0.63000
# 101                                           0.46000
# 102                                           0.00001
#
# [102 rows x 8 columns]

# %% [markdown]
# **Question 2.3** You should have found that the values in "Total Pay" column are strings (text). It doesn't make sense to take the average of the text values, so we need to convert them to numbers if we want to do this. Extract the first value in the "Total Pay" column.  It's Mark Hurd's pay in 2015, in *millions* of dollars.  Call it `mark_hurd_pay_string`.

# %%
#your code here.
mark_hurd_pay_string = raw_compensation.loc[1]['Total Pay']
mark_hurd_pay_string
# Out:
# '$53.25 '

# %% [markdown]
# **Question 2.3.1** Using code, `mark_hurd_pay_string` to a number of *dollars*.
# <br>Hint: you can use split method.

# %%
#your code here
dollars = float(mark_hurd_pay_string.split('$')[1].split(' ')[0])
dollars
# Out:
# 53.25

# %% [markdown]
# To compute the average pay, we need to do this for every CEO. But that looks like it would involve copying this code 102 times.
# <br>**Question 2.3.2.** Copy the expression you used to compute `mark_hurd_pay` as the `return` expression of the function below, but replace the specific `mark_hurd_pay_string` with the generic `pay_string` name specified in the first line of the `def` statement.

# %%
#your code here
def convert_pay_string_to_number(pay_string):
    dollars = float(pay_string.split('$')[1].split(' ')[0])
    return dollars

# %%
#run this cell to check if your code is correct

# %%
convert_pay_string_to_number('$42')
# Out:
# 42.0

# %% [markdown]
# **Question 2.3.3** Using apply, make a Daatframe that's a copy of raw_compensation with one more column called "Total_Pay_Dollars". It should be the result of applying convert_pay_string_to_number to the "Total Pay" column, as we did above. Call the new df compensation.

# %%
raw_compensation['Total_Pay_Dollars']=raw_compensation['Total Pay'].apply(convert_pay_string_to_number)
raw_compensation
# Out:
#                     Name                 Company (Headquarters) Total Pay  \
# Rank
# 1          Mark V. Hurd*                  Oracle (Redwood City)   $53.25
# 2         Safra A. Catz*                  Oracle (Redwood City)   $53.24
# 3         Robert A. Iger                  Walt Disney (Burbank)   $44.91
# 4       Marissa A. Mayer                     Yahoo! (Sunnyvale)   $35.98
# 5           Marc Benioff         salesforce.com (San Francisco)   $33.36
# ...                  ...                                    ...       ...
# 98    Gregory N. Roberts  A-Mark Precious Metals (Santa Monica)    $0.94
# 99       Jose L. Laparte                 PriceSmart (San Diego)    $0.81
# 100          Jack Dorsey                Twitter (San Francisco)    $0.07
# 101         Elon R. Musk               Tesla Motors (Palo Alto)    $0.04
# 102     Lawrence Page***               Alphabet (Mountain View)    $0.00
#
#      % Change Cash Pay Equity Pay Other Pay  \
# Rank
# 1         NaN   $0.95     $52.27     $0.02
# 2         NaN   $0.95     $52.27     $0.02
# 3         -3%  $24.89     $17.28     $2.74
# 4        -15%   $1.00     $34.43     $0.55
# 5        -16%   $4.65     $27.26     $1.45
# ...       ...      ...        ...       ...
# 98       -11%   $0.93      $0.00     $0.02
# 99        -7%   $0.71      $0.00     $0.10
# 100       NaN   $0.00      $0.00     $0.07
# 101        6%   $0.04      $0.00     $0.00
# 102        0%   $0.00      $0.00     $0.00
#
#       Ratio of CEO pay to average industry worker pay  Total_Pay_Dollars
# Rank
# 1                                           362.00000              53.25
# 2                                           362.00000              53.24
# 3                                           477.00000              44.91
# 4                                           342.00000              35.98
# 5                                           338.00000              33.36
# ...                                               ...                ...
# 98                                           17.00000               0.94
# 99                                           32.00000               0.81
# 100                                           0.63000               0.07
# 101                                           0.46000               0.04
# 102                                           0.00001               0.00
#
# [102 rows x 9 columns]

# %% [markdown]
# **Question 2.4.** Companies pay executives in a variety of ways: directly in cash; by granting stock or other "equity" in the company; or with ancillary benefits (like private jets).  Compute the proportion of each CEO's pay that was cash.  (Your answer should be an array of numbers, one for each CEO in the dataset.)

# %%
#your code here
cash = np.array(raw_compensation['Cash Pay'].apply(convert_pay_string_to_number))
equity=np.array(raw_compensation['Equity Pay'].apply(convert_pay_string_to_number))
other =np.array(raw_compensation['Other Pay'].apply(convert_pay_string_to_number))
total = cash + equity + other
cash_fraction = (cash/total)
cash_fraction
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide
# array([0.01784373, 0.01784373, 0.55421955, 0.02779322, 0.13938849,
#        0.48711755, 0.19555354, 0.12437059, 0.25993884, 0.35196687,
#        0.3075693 , 0.22138635, 0.13133515, 0.17071823, 0.23099415,
#        0.06730769, 0.13043478, 0.28004957, 0.33229814, 0.15355805,
#        0.2935719 , 0.21814543, 0.31100478, 0.25068871, 0.2299169 ,
#        0.17003484, 0.31795947, 0.26188786, 0.28377412, 0.15654718,
#        0.38199513, 0.28934426, 0.20361248, 0.47611203, 0.45643154,
#        0.36402027, 0.2177626 , 0.24742268, 0.4252462 , 0.26079137,
#        0.18361836, 0.14458955, 0.33333333, 0.10823755, 0.20905588,
#        0.97276265, 0.22979552, 0.22767419, 0.37893701, 0.25175527,
#        0.73895582, 0.37018256, 0.24102564, 0.21314952, 0.20553781,
#        0.23344191, 0.33627343, 0.3875969 , 0.56158192, 0.11771429,
#        0.35280374, 0.24463007, 0.25      , 0.23712575, 0.43325243,
#        0.31424936, 0.46423927, 0.32585752, 0.24766977, 0.98755187,
#        0.27184466, 0.96207865, 0.31831395, 0.81979321, 0.23795181,
#        0.17530488, 0.21172638, 0.37162162, 0.27288136, 0.26949153,
#        0.55148342, 0.3597786 , 0.        , 0.47154472, 0.47154472,
#        0.29753915, 0.16235294, 0.48648649, 0.46938776, 0.32439678,
#        0.98958333, 0.61130742, 0.67021277, 0.75510204, 0.50837989,
#        0.98809524, 0.97402597, 0.97894737, 0.87654321, 0.        ,
#        1.        ,        nan])

# %% [markdown]
# ##### Alright, back to our CEOs.  Check out the "% Change" column in `compensation`.  It shows the percentage increase in the CEO's pay from the previous year.  For CEOs with no previous year on record, it instead says "(No previous year)".  The values in this column are *strings*, not numbers, so like the "Total Pay" column, it's not usable without a bit of extra work.
#
# Given your current pay and the percentage increase from the previous year, you can compute your previous year's pay.  For example, if your pay is \\$100 this year, and that's an increase of 50% from the previous year, then your previous year's pay was $\frac{\$100}{1 + \frac{50}{100}}$, or around \$66.66.
#
# **Question 2.5.** Create a new table called `with_previous_compensation`.  It should be a copy of `compensation`, but with the "(No previous year)" CEOs filtered out, and with an extra column called "Previous_Total_Pay".  That column should have each CEO's pay in 2014.
#
# *Hint:* This question takes several steps, but each one is still something you've seen before.  Take it one step at a time, using as many lines as you need.  You can print out your results after each step to make sure you're on the right track.
#
# *Hint 2:* You'll need to define a function to convert percentage strings, like `-15%`, to numbers.  You can do that just above your other code.
#
# *Hint 3:* If you see an error saying "unsupported operand type(s) for +: 'int' and 'Series'", try switching the order of your operation. Instead of writing something like `1 + series`, write `series + 1`.

# %%
#your code Here
def convert(val):
    return int(val.replace('%',""))
#another function to calculate the previous year compensention
def prev(x,y):
    return (x/(1+(y/100)))
raw_compensation = raw_compensation.dropna(subset =['% Change'])
raw_compensation['% Change'] = raw_compensation['% Change'].apply(convert)
raw_compensation['Total_Pay_Dollars']=raw_compensation['Total Pay'].apply(convert_pay_string_to_number)
with_previous_compensation = raw_compensation
with_previous_compensation["Previous_Total_Pay"]=prev(with_previous_compensation['Total_Pay_Dollars'],with_previous_compensation['% Change'])
with_previous_compensation
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#                     Name                 Company (Headquarters) Total Pay  \
# Rank
# 3         Robert A. Iger                  Walt Disney (Burbank)   $44.91
# 4       Marissa A. Mayer                     Yahoo! (Sunnyvale)   $35.98
# 5           Marc Benioff         salesforce.com (San Francisco)   $33.36
# 6     John H. Hammergren               McKesson (San Francisco)   $24.84
# 7         John S. Watson                    Chevron (San Ramon)   $22.04
# ...                  ...                                    ...       ...
# 97         David G. Hirz        Smartæ& Final Stores (Commerce)    $1.53
# 98    Gregory N. Roberts  A-Mark Precious Metals (Santa Monica)    $0.94
# 99       Jose L. Laparte                 PriceSmart (San Diego)    $0.81
# 101         Elon R. Musk               Tesla Motors (Palo Alto)    $0.04
# 102     Lawrence Page***               Alphabet (Mountain View)    $0.00
#
#       % Change Cash Pay Equity Pay Other Pay  \
# Rank
# 3           -3  $24.89     $17.28     $2.74
# 4          -15   $1.00     $34.43     $0.55
# 5          -16   $4.65     $27.26     $1.45
# 6           -4  $12.10     $12.37     $0.37
# 7          -15   $4.31     $14.68     $3.05
# ...        ...      ...        ...       ...
# 97         -66   $1.50      $0.00     $0.04
# 98         -11   $0.93      $0.00     $0.02
# 99          -7   $0.71      $0.00     $0.10
# 101          6   $0.04      $0.00     $0.00
# 102          0   $0.00      $0.00     $0.00
#
#       Ratio of CEO pay to average industry worker pay  Total_Pay_Dollars  \
# Rank
# 3                                           477.00000              44.91
# 4                                           342.00000              35.98
# 5                                           338.00000              33.36
# 6                                           222.00000              24.84
# 7                                           183.00000              22.04
# ...                                               ...                ...
# 97                                           26.00000               1.53
# 98                                           17.00000               0.94
# 99                                           32.00000               0.81
# 101                                           0.46000               0.04
# 102                                           0.00001               0.00
#
#       Previous_Total_Pay
# Rank
# 3              46.298969
# 4              42.329412
# 5              39.714286
# 6              25.875000
# 7              25.929412
# ...                  ...
# 97              4.500000
# 98              1.056180
# 99              0.870968
# 101             0.037736
# 102             0.000000
#
# [81 rows x 10 columns]

# %% [markdown]
# ## 3. Data Cleaning

# %%
gfm_data = pd.read_csv('gfm_data.csv')
gfm_data
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# 1     Window Rock, AZ      1862040.0  1000000.0                  205
# 2        Randolph, NJ       954793.0  1200000.0                  215
# 3      Scottsdale, AZ       673179.0  1000000.0                  131
# 4           Tyler, TX       570529.0   750000.0                  175
# ..                ...            ...        ...                  ...
# 833      Brooklyn, NY        17348.0    20000.0                  160
# 834       Brandon, VT        19300.0    17000.0                  200
# 835       Amherst, MA        21435.0   300000.0                  110
# 836  Johnson City, TN        16405.0    70000.0                  173
# 837     Santa Ana, CA        17905.0    50000.0                  147
#
#     Number_of_Donors FB_Shares  \
# 0              72.5K      118K
# 1              21.9K     71.7K
# 2              18.3K     16.4K
# 3              10.3K     21.3K
# 4              24.3K      5.5K
# ..               ...       ...
# 833              366       214
# 834              279      2.5K
# 835              318       868
# 836              148       379
# 837               45       242
#
#                                                   Text
# 0    On August 23rd my son was shot multiple times ...
# 1    The Navajo Nation COVID-19 Fund has been estab...
# 2    On Sunday, April 12, Sylvia Leroy, a pregnant ...
# 3    First, thank you for being here. Tommy Rivers ...
# 4    My name is Melissa Green and I am the mother o...
# ..                                                 ...
# 833  The need for community and collective healing ...
# 834  I am 35 years old and was born with cerebral p...
# 835  Greetings,My name is Nyanyika Banda. I am a ch...
# 836  My wife, Roni, and I have faced many  health c...
# 837  No matter where life has lead us, our past for...
#
# [838 rows x 9 columns]

# %% [markdown]
# Here, each row represents a different fundraiser, also called a campaign.
#
# There are nine columns of data, reading from left to right:
#
# 1. `Category`: Describes the type of fundraiser. There are 14 different categories of fundraiser represented in our dataset: 'Animals', 'Business', 'Community', 'Competition', 'Creative', 'Emergency', 'Event', 'Faith', 'Family', 'Medical', 'Memorial', 'Newlywed', 'Sports', and 'Wishes'.
#
# 2. `Title`: The title of the fundraiser, which describes the fundraiser in a few words.
#
# 3. `Location`: The location where the fundraiser takes place, stored as "city, state", e.g. "San Diego, CA".
#
# 4. `Amount_Raised`: The total amount of money donated, measured in dollars.
#
# 5. `Goal`: The total amount of money that the fundraiser originally hopes to receive (measured in dollars).
#
# 6. `Days_of_Fundraising`: The number of days for which the fundraiser has been actively soliciting donations.
#
# 7. `Number_of_Donors`: The number of people who donated to the fundraiser.
#
# 8. `FB_Shares`: The number of times the fundraiser has been shared through Facebook.
#
# 9. `Text`: The text description that accompanies the fundraiser, usually describing why funds are being raised.
#
# In the `Number_of_Donors` column and the `FB_Shares` column, entries are stored as strings, and large numbers are abbreviated by using "K" to indicate thousands. For example, an entry `3K` would correspond to 3 * 1000 = 3000.
#
# Note that much of the data for each fundraiser is determined by the user who creates the campaign. When creating a campaign, the user selects an appropriate category and title, chooses the location, sets the fundraising goal, and adds the text description.

# %% [markdown]
# As a data scientist, data cleaning is where you will spend a significant portion of your time. This project is no different!
#
# Let's start by examining the `Number_of_Donors` and `FB_Shares` columns. The values in these columns are strings, not integers, so we can't actually do things like compare values numerically. Moreover, some values are in thousands, such as '72.5K', and others are fewer than 1000, such as '366'. Let's get this data in a more usable format.
#
# **Question 3.1.1** Define a function named `convert_units` which converts a string representation of a number to an integer. This function should work whether or not the string representation has a ‘K’ in it (representing thousands).
#
# *Hint*: Use a [string method](https://docs.python.org/3/library/stdtypes.html#string-methods) to deal with the 'K'.

# %%
#your code
def convert_units(string_rep):
    if string_rep.isnumeric():
        return int(string_rep)
    else:
        return  int(float(string_rep.replace('K',''))*1000)

convert_units('45K')
# Out:
# 45000

# %% [markdown]
# **Question 3.1.2.** Overwrite the columns for `Number_of_Donors` and `FB_Shares` with columns of the same name, but containing integers instead of strings. The dataframe should still be named `gfm_data`.
#
# *Note*: The names of all the columns **must** stay the same and the order of the columns **must** stay the same.

# %%
gfm_data['Number_of_Donors'] = gfm_data['Number_of_Donors'].apply(convert_units)
gfm_data['FB_Shares'] = gfm_data['FB_Shares'].apply(convert_units)
gfm_data
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# 1     Window Rock, AZ      1862040.0  1000000.0                  205
# 2        Randolph, NJ       954793.0  1200000.0                  215
# 3      Scottsdale, AZ       673179.0  1000000.0                  131
# 4           Tyler, TX       570529.0   750000.0                  175
# ..                ...            ...        ...                  ...
# 833      Brooklyn, NY        17348.0    20000.0                  160
# 834       Brandon, VT        19300.0    17000.0                  200
# 835       Amherst, MA        21435.0   300000.0                  110
# 836  Johnson City, TN        16405.0    70000.0                  173
# 837     Santa Ana, CA        17905.0    50000.0                  147
#
#      Number_of_Donors  FB_Shares  \
# 0               72500     118000
# 1               21900      71700
# 2               18300      16400
# 3               10300      21300
# 4               24300       5500
# ..                ...        ...
# 833               366        214
# 834               279       2500
# 835               318        868
# 836               148        379
# 837                45        242
#
#                                                   Text
# 0    On August 23rd my son was shot multiple times ...
# 1    The Navajo Nation COVID-19 Fund has been estab...
# 2    On Sunday, April 12, Sylvia Leroy, a pregnant ...
# 3    First, thank you for being here. Tommy Rivers ...
# 4    My name is Melissa Green and I am the mother o...
# ..                                                 ...
# 833  The need for community and collective healing ...
# 834  I am 35 years old and was born with cerebral p...
# 835  Greetings,My name is Nyanyika Banda. I am a ch...
# 836  My wife, Roni, and I have faced many  health c...
# 837  No matter where life has lead us, our past for...
#
# [838 rows x 9 columns]

# %% [markdown]
# Next, let's add some columns derived from existing columns.
#
# **Question 3.2.** Create a new dataframe called `gfm_campaigns` that has the same columns as `gfm`, plus two more:
#
# 1. `Proportion_Raised`, which has the proportion of the overall goal that the campaign raised. This proportion should be rounded (not truncated) to **3** decimal places.
# 2. `Average_Donation_Amount`, which has the average donation amount per donor. Since this is a dollar amount, it should be rounded (not truncated) to **2** decimal places.

# %%
#your code Here
def divide(x,y,z):
    return round((x/y),z)

gfm_campaigns = gfm_data
gfm_campaigns['Proportion_Raised'] = divide(gfm_campaigns['Amount_Raised'],gfm_campaigns['Goal'],3)
gfm_campaigns['Average_Donation_Amount'] =  divide(gfm_campaigns['Amount_Raised'],gfm_campaigns['Number_of_Donors'],2)
gfm_campaigns
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# 1     Window Rock, AZ      1862040.0  1000000.0                  205
# 2        Randolph, NJ       954793.0  1200000.0                  215
# 3      Scottsdale, AZ       673179.0  1000000.0                  131
# 4           Tyler, TX       570529.0   750000.0                  175
# ..                ...            ...        ...                  ...
# 833      Brooklyn, NY        17348.0    20000.0                  160
# 834       Brandon, VT        19300.0    17000.0                  200
# 835       Amherst, MA        21435.0   300000.0                  110
# 836  Johnson City, TN        16405.0    70000.0                  173
# 837     Santa Ana, CA        17905.0    50000.0                  147
#
#      Number_of_Donors  FB_Shares  \
# 0               72500     118000
# 1               21900      71700
# 2               18300      16400
# 3               10300      21300
# 4               24300       5500
# ..                ...        ...
# 833               366        214
# 834               279       2500
# 835               318        868
# 836               148        379
# 837                45        242
#
#                                                   Text  Proportion_Raised  \
# 0    On August 23rd my son was shot multiple times ...              0.766
# 1    The Navajo Nation COVID-19 Fund has been estab...              1.862
# 2    On Sunday, April 12, Sylvia Leroy, a pregnant ...              0.796
# 3    First, thank you for being here. Tommy Rivers ...              0.673
# 4    My name is Melissa Green and I am the mother o...              0.761
# ..                                                 ...                ...
# 833  The need for community and collective healing ...              0.867
# 834  I am 35 years old and was born with cerebral p...              1.135
# 835  Greetings,My name is Nyanyika Banda. I am a ch...              0.071
# 836  My wife, Roni, and I have faced many  health c...              0.234
# 837  No matter where life has lead us, our past for...              0.358
#
#      Average_Donation_Amount
# 0                      31.70
# 1                      85.02
# 2                      52.17
# 3                      65.36
# 4                      23.48
# ..                       ...
# 833                    47.40
# 834                    69.18
# 835                    67.41
# 836                   110.84
# 837                   397.89
#
# [838 rows x 11 columns]

# %% [markdown]
# **Question 3.3** Create a new dataframe called `gfm_success`, which has all the information from the `gfm_campaigns` dataframe plus a new column titled `How_Successful` that indicates how successful a campaign was, depending on its `Proportion_Raised`. If x is the proportion raised, we use the table below to define how successful a campaign is.
#
# | Range             | How_Successful |
# | ----------------- | ------------------ |
# | 0.0 $\leq$ x $\leq$ 0.20 | 'highly unsuccessful' |
# | 0.20 $<$ x $\leq$ 0.50 | 'moderately unsuccessful' |
# | 0.50 $<$ x $\leq$ 0.80 | 'moderately successful' |
# | 0.80 $<$ x $<$ 1.0 | 'highly successful' |
# | x $\geq$ 1.0 | 'extremely successful' |

# %%
#your code Here
def success(x):
    if 0.0 <= x and x <= 0.20:
        return 'highly unsuccessful'
    elif 0.20 <= x and x <=  0.50:
        return  'moderately unsuccessful'
    elif 0.50 <= x and x <=  0.80:
        return 'moderately successful'
    elif 0.80 <= x and x <=  1.0:
        return 'highly successful'
    elif 1.0 <= x:
        return 'extremely successful'
    
gfm_success = gfm_campaigns
gfm_success['How_Successful']=gfm_success['Proportion_Raised'].apply(success)
gfm_success
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# 1     Window Rock, AZ      1862040.0  1000000.0                  205
# 2        Randolph, NJ       954793.0  1200000.0                  215
# 3      Scottsdale, AZ       673179.0  1000000.0                  131
# 4           Tyler, TX       570529.0   750000.0                  175
# ..                ...            ...        ...                  ...
# 833      Brooklyn, NY        17348.0    20000.0                  160
# 834       Brandon, VT        19300.0    17000.0                  200
# 835       Amherst, MA        21435.0   300000.0                  110
# 836  Johnson City, TN        16405.0    70000.0                  173
# 837     Santa Ana, CA        17905.0    50000.0                  147
#
#      Number_of_Donors  FB_Shares  \
# 0               72500     118000
# 1               21900      71700
# 2               18300      16400
# 3               10300      21300
# 4               24300       5500
# ..                ...        ...
# 833               366        214
# 834               279       2500
# 835               318        868
# 836               148        379
# 837                45        242
#
#                                                   Text  Proportion_Raised  \
# 0    On August 23rd my son was shot multiple times ...              0.766
# 1    The Navajo Nation COVID-19 Fund has been estab...              1.862
# 2    On Sunday, April 12, Sylvia Leroy, a pregnant ...              0.796
# 3    First, thank you for being here. Tommy Rivers ...              0.673
# 4    My name is Melissa Green and I am the mother o...              0.761
# ..                                                 ...                ...
# 833  The need for community and collective healing ...              0.867
# 834  I am 35 years old and was born with cerebral p...              1.135
# 835  Greetings,My name is Nyanyika Banda. I am a ch...              0.071
# 836  My wife, Roni, and I have faced many  health c...              0.234
# 837  No matter where life has lead us, our past for...              0.358
#
#      Average_Donation_Amount           How_Successful
# 0                      31.70    moderately successful
# 1                      85.02     extremely successful
# 2                      52.17    moderately successful
# 3                      65.36    moderately successful
# 4                      23.48    moderately successful
# ..                       ...                      ...
# 833                    47.40        highly successful
# 834                    69.18     extremely successful
# 835                    67.41      highly unsuccessful
# 836                   110.84  moderately unsuccessful
# 837                   397.89  moderately unsuccessful
#
# [838 rows x 12 columns]

# %% [markdown]
# Notice that the `Text` column contains the description of the campaign, which visitors to the campaign page will see. As part of this project, we'd like to explore what makes a description successful in raising money. For example, do longer descriptions raise more money or is better to keep things brief? Are there certain keywords like "mother" or "father" associated with better fundraising outcomes? To answer these types of questions, we'll need to look inside the `Text` column. The data cleaning below will help us extract the information we need more easily.
#
# **Question 3.4.** Create a new dataframe called `gfm`, which has all the information from the `gfm_success` dataframe plus a new column called `Num_Chars` with the length of the text description for each campaign, as an int.

# %%
#An another function
def char(x):
    return len(x)
gfm = gfm_success
gfm['Num_Chars'] = gfm['Text'].apply(char)
gfm
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# 1     Window Rock, AZ      1862040.0  1000000.0                  205
# 2        Randolph, NJ       954793.0  1200000.0                  215
# 3      Scottsdale, AZ       673179.0  1000000.0                  131
# 4           Tyler, TX       570529.0   750000.0                  175
# ..                ...            ...        ...                  ...
# 833      Brooklyn, NY        17348.0    20000.0                  160
# 834       Brandon, VT        19300.0    17000.0                  200
# 835       Amherst, MA        21435.0   300000.0                  110
# 836  Johnson City, TN        16405.0    70000.0                  173
# 837     Santa Ana, CA        17905.0    50000.0                  147
#
#      Number_of_Donors  FB_Shares  \
# 0               72500     118000
# 1               21900      71700
# 2               18300      16400
# 3               10300      21300
# 4               24300       5500
# ..                ...        ...
# 833               366        214
# 834               279       2500
# 835               318        868
# 836               148        379
# 837                45        242
#
#                                                   Text  Proportion_Raised  \
# 0    On August 23rd my son was shot multiple times ...              0.766
# 1    The Navajo Nation COVID-19 Fund has been estab...              1.862
# 2    On Sunday, April 12, Sylvia Leroy, a pregnant ...              0.796
# 3    First, thank you for being here. Tommy Rivers ...              0.673
# 4    My name is Melissa Green and I am the mother o...              0.761
# ..                                                 ...                ...
# 833  The need for community and collective healing ...              0.867
# 834  I am 35 years old and was born with cerebral p...              1.135
# 835  Greetings,My name is Nyanyika Banda. I am a ch...              0.071
# 836  My wife, Roni, and I have faced many  health c...              0.234
# 837  No matter where life has lead us, our past for...              0.358
#
#      Average_Donation_Amount           How_Successful  Num_Chars
# 0                      31.70    moderately successful        964
# 1                      85.02     extremely successful        824
# 2                      52.17    moderately successful       1651
# 3                      65.36    moderately successful       1461
# 4                      23.48    moderately successful       1241
# ..                       ...                      ...        ...
# 833                    47.40        highly successful       4098
# 834                    69.18     extremely successful       3006
# 835                    67.41      highly unsuccessful       5844
# 836                   110.84  moderately unsuccessful       6745
# 837                   397.89  moderately unsuccessful        118
#
# [838 rows x 13 columns]

# %% [markdown]
# **Question 3.5** Overwrite the `Text` column in the `gfm` dataframe so that all the descriptions appear in lowercase.
#
# *Hint:* Check out Python's built-in [string methods](https://docs.python.org/3/library/stdtypes.html#string-methods).

# %%
#your code here
def lowe(x):
    return x.lower()
gfm['Text'] = gfm['Text'].apply(lowe)
gfm
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# 1     Window Rock, AZ      1862040.0  1000000.0                  205
# 2        Randolph, NJ       954793.0  1200000.0                  215
# 3      Scottsdale, AZ       673179.0  1000000.0                  131
# 4           Tyler, TX       570529.0   750000.0                  175
# ..                ...            ...        ...                  ...
# 833      Brooklyn, NY        17348.0    20000.0                  160
# 834       Brandon, VT        19300.0    17000.0                  200
# 835       Amherst, MA        21435.0   300000.0                  110
# 836  Johnson City, TN        16405.0    70000.0                  173
# 837     Santa Ana, CA        17905.0    50000.0                  147
#
#      Number_of_Donors  FB_Shares  \
# 0               72500     118000
# 1               21900      71700
# 2               18300      16400
# 3               10300      21300
# 4               24300       5500
# ..                ...        ...
# 833               366        214
# 834               279       2500
# 835               318        868
# 836               148        379
# 837                45        242
#
#                                                   Text  Proportion_Raised  \
# 0    on august 23rd my son was shot multiple times ...              0.766
# 1    the navajo nation covid-19 fund has been estab...              1.862
# 2    on sunday, april 12, sylvia leroy, a pregnant ...              0.796
# 3    first, thank you for being here. tommy rivers ...              0.673
# 4    my name is melissa green and i am the mother o...              0.761
# ..                                                 ...                ...
# 833  the need for community and collective healing ...              0.867
# 834  i am 35 years old and was born with cerebral p...              1.135
# 835  greetings,my name is nyanyika banda. i am a ch...              0.071
# 836  my wife, roni, and i have faced many  health c...              0.234
# 837  no matter where life has lead us, our past for...              0.358
#
#      Average_Donation_Amount           How_Successful  Num_Chars
# 0                      31.70    moderately successful        964
# 1                      85.02     extremely successful        824
# 2                      52.17    moderately successful       1651
# 3                      65.36    moderately successful       1461
# 4                      23.48    moderately successful       1241
# ..                       ...                      ...        ...
# 833                    47.40        highly successful       4098
# 834                    69.18     extremely successful       3006
# 835                    67.41      highly unsuccessful       5844
# 836                   110.84  moderately unsuccessful       6745
# 837                   397.89  moderately unsuccessful        118
#
# [838 rows x 13 columns]

# %% [markdown]
# **Question 3.6.** Set `cutoff` to be the smallest number of characters for which we will consider a text description to be long, if we want the groups to be about the same size.
#
# *Hint*: We may not be able to split the dataset into groups of the exact same size. What is the best we can do? Use a measure of center.

# %%
cutoff = int(gfm['Text'].apply(len).mean())
cutoff
# Out:
# 1938

# %% [markdown]
# Now define a long description to be a description where the number of characters is ***at least*** as long as `cutoff` and a short description to be a description where the number of characters is less than `cutoff`.
# Make 2 dataframe for long and short

# %%
#your code Here
long_df = gfm[gfm['Text'].apply(len) <= cutoff]
short_df = gfm[gfm['Text'].apply(len) >= cutoff]
#short_df
long_df
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 829   Wishes                                    Freddy Sheehan
# 830   Wishes                  Quality of life for Sean Gilbert
# 831   Wishes         Queer Creative & Spiritual Retreat Space!
# 832   Wishes    Homeless queer immigrant in need of assistance
# 837   Wishes                            Our Roots - Yahchouche
#
#             Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0        Kenosha, WI      2297930.0  3000000.0                   93
# 1    Window Rock, AZ      1862040.0  1000000.0                  205
# 2       Randolph, NJ       954793.0  1200000.0                  215
# 3     Scottsdale, AZ       673179.0  1000000.0                  131
# 4          Tyler, TX       570529.0   750000.0                  175
# ..               ...            ...        ...                  ...
# 829       Sparks, NV        17506.0    30000.0                  174
# 830        Hiram, GA        17500.0    16000.0                   90
# 831     Brooklyn, NY        17459.0   100000.0                  105
# 832      Houston, TX        17426.0    25000.0                  139
# 837    Santa Ana, CA        17905.0    50000.0                  147
#
#      Number_of_Donors  FB_Shares  \
# 0               72500     118000
# 1               21900      71700
# 2               18300      16400
# 3               10300      21300
# 4               24300       5500
# ..                ...        ...
# 829                64        518
# 830                60         41
# 831               234         70
# 832               896         66
# 837                45        242
#
#                                                   Text  Proportion_Raised  \
# 0    on august 23rd my son was shot multiple times ...              0.766
# 1    the navajo nation covid-19 fund has been estab...              1.862
# 2    on sunday, april 12, sylvia leroy, a pregnant ...              0.796
# 3    first, thank you for being here. tommy rivers ...              0.673
# 4    my name is melissa green and i am the mother o...              0.761
# ..                                                 ...                ...
# 829  as some of you may or may not know freddy shee...              0.584
# 830  i'm not gonna bore you with a story of of the ...              1.094
# 831  i'm myles e. johnson, a 29-year-old black quee...              0.175
# 832  edit: i’m homeless now. hi my name is selena i...              0.697
# 837  no matter where life has lead us, our past for...              0.358
#
#      Average_Donation_Amount           How_Successful  Num_Chars
# 0                      31.70    moderately successful        964
# 1                      85.02     extremely successful        824
# 2                      52.17    moderately successful       1651
# 3                      65.36    moderately successful       1461
# 4                      23.48    moderately successful       1241
# ..                       ...                      ...        ...
# 829                   273.53    moderately successful        473
# 830                   291.67     extremely successful        549
# 831                    74.61      highly unsuccessful       1888
# 832                    19.45    moderately successful        780
# 837                   397.89  moderately unsuccessful        118
#
# [529 rows x 13 columns]

# %% [markdown]
# Next, we can run some text analysis to determine whether specific words in the `Text` are associated with a higher or lower `Average_Donation_Amount`. More specifically, do donors find specific words found in the description of a campaign impactful? For example, we might conjecture that words relating to family like "father", "daughter", "son", etc. are associated with higher average donation amounts.
#
# Which *three* words do you think are impactful to donors? Store any three lowercase words you think are linked to higher average donations in a list called `impactful_words`.

# %%
# gfm_high_impact = gfm[gfm['How_Successful']=='extremely successful']
# gfm_high_impact.to_csv("gfm_data1.csv",index=False)

# %%
impactful_words=['my','daughter','son']

# %% [markdown]
# **Question 3.7** Create a new dataframe called `gfm_impactful`, which contains the information from `gfm` plus a column named `Has_Impactful` which is True/False depending whether the campaign contains at least one impactful word or not.

# %%
#your code here
def check(x):
    return any(impactful_word in x for impactful_word in impactful_words)
gfm_impactful=gfm
gfm_impactful['Has_Impactful']=gfm['Text'].apply(check)
gfm_impactful
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# 1     Window Rock, AZ      1862040.0  1000000.0                  205
# 2        Randolph, NJ       954793.0  1200000.0                  215
# 3      Scottsdale, AZ       673179.0  1000000.0                  131
# 4           Tyler, TX       570529.0   750000.0                  175
# ..                ...            ...        ...                  ...
# 833      Brooklyn, NY        17348.0    20000.0                  160
# 834       Brandon, VT        19300.0    17000.0                  200
# 835       Amherst, MA        21435.0   300000.0                  110
# 836  Johnson City, TN        16405.0    70000.0                  173
# 837     Santa Ana, CA        17905.0    50000.0                  147
#
#      Number_of_Donors  FB_Shares  \
# 0               72500     118000
# 1               21900      71700
# 2               18300      16400
# 3               10300      21300
# 4               24300       5500
# ..                ...        ...
# 833               366        214
# 834               279       2500
# 835               318        868
# 836               148        379
# 837                45        242
#
#                                                   Text  Proportion_Raised  \
# 0    on august 23rd my son was shot multiple times ...              0.766
# 1    the navajo nation covid-19 fund has been estab...              1.862
# 2    on sunday, april 12, sylvia leroy, a pregnant ...              0.796
# 3    first, thank you for being here. tommy rivers ...              0.673
# 4    my name is melissa green and i am the mother o...              0.761
# ..                                                 ...                ...
# 833  the need for community and collective healing ...              0.867
# 834  i am 35 years old and was born with cerebral p...              1.135
# 835  greetings,my name is nyanyika banda. i am a ch...              0.071
# 836  my wife, roni, and i have faced many  health c...              0.234
# 837  no matter where life has lead us, our past for...              0.358
#
#      Average_Donation_Amount           How_Successful  Num_Chars  \
# 0                      31.70    moderately successful        964
# 1                      85.02     extremely successful        824
# 2                      52.17    moderately successful       1651
# 3                      65.36    moderately successful       1461
# 4                      23.48    moderately successful       1241
# ..                       ...                      ...        ...
# 833                    47.40        highly successful       4098
# 834                    69.18     extremely successful       3006
# 835                    67.41      highly unsuccessful       5844
# 836                   110.84  moderately unsuccessful       6745
# 837                   397.89  moderately unsuccessful        118
#
#      Has_Impactful
# 0             True
# 1            False
# 2             True
# 3             True
# 4             True
# ..             ...
# 833           True
# 834           True
# 835           True
# 836           True
# 837          False
#
# [838 rows x 14 columns]

# %% [markdown]
# ## 4. Google Play Store
#
# In this problem, we will explore the [Google Play Store Apps Dataset](https://www.kaggle.com/lava18/google-play-store-apps), scraped from the Google Play Store.

# %%
# run this cell to load the data
apps = pd.read_csv('googleplaystore.csv')
apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %% [markdown]
# Each row in the table is an app. Here are descriptions of some of the columns.
# - **Category** Category the app belongs to
# - **Rating** Overall user rating of the app (as when scraped)
# - **Reviews** Number of user reviews for the app (as when scraped)
# - **Installs** Number of user downloads/installs for the app (as when scraped)
#
# Notice that we did not set the index, even though it looks like the app name would be a good candidate. This is because the app names are not unique! We can verify this with the help of a `numpy` function called `np.unique`. This function takes in an array and outputs an array with all duplicates removed.
#
# We see above that the table has 10,825 rows. This means that there are 10,825 apps in the dataset. But let's calculate how many unique names there are:

# %%
len(np.unique(apps.get('App')))
# Out:
# 9660

# %% [markdown]
# So there must be duplicates!
#
# Because there are duplicates, the app name is not a good row label. In fact, there is no good row label in this case. In situations like this, we'll leave the index as-is.

# %% [markdown]
# **Question 4.1.** Assign `by_content` to a dataframe which counts the number of apps per Content Rating. List the Content Ratings alphabetically.
# <br>
# Hint:You can use groupby

# %%
#your code here
apps.groupby('Content Rating',sort = True).count()['App']
# Out:
# Content Rating
# Adults only 18+       3
# Everyone           8714
# Everyone 10+        414
# Mature 17+          499
# Teen               1208
# Unrated               2
# Name: App, dtype: int64

# %% [markdown]
# **Question 4.2.** Compute the number of apps in the dataset that have 1.5 stars or lower, and save the result in `bad_apps` and compute the number of apps in the dataset that have 4 stars or higher, and save the results in `good_apps`.

# %%
bad_apps=apps[apps['Rating']<=1.5]
bad_apps
# Out:
#                                                     App            Category  \
# 625                             House party - live chat              DATING
# 4127                                  Speech Therapy: F              FAMILY
# 5151                                      Clarksburg AH             MEDICAL
# 5978                      Truck Driving Test Class 3 BC              FAMILY
# 6008                                    BD Provider App  HEALTH_AND_FITNESS
# 6319                   BJ Bridge Standard American 2018                GAME
# 6490                                             MbH BM             MEDICAL
# 7126                                   CB Mobile Access             FINANCE
# 7144                                      CB Mobile Biz             FINANCE
# 7254                                           CF Climb           LIFESTYLE
# 7383                                     Thistletown CI        PRODUCTIVITY
# 7427                                     CJ DVD Rentals       COMMUNICATION
# 7677                                 Hercules CP Mobile               TOOLS
# 7806                                        CR Magazine            BUSINESS
# 7926                               Tech CU Card Manager             FINANCE
# 8258                                            Quiz DC                GAME
# 8820                                     DS Creator 2.0               TOOLS
# 8875                                     DT future1 cam               TOOLS
# 10082                                        EY TaxChat             FINANCE
# 10324                    FE Mechanical Engineering Prep              FAMILY
# 10400           Familial Hypercholesterolaemia Handbook             MEDICAL
# 10562                                       FK Atlantas              SPORTS
# 10591  Lottery Ticket Checker - Florida Results & Lotto               TOOLS
#
#        Rating Reviews  Size Installs  Type  Price Content Rating  \
# 625       1.0       1  9.2M      10+  Free      0     Mature 17+
# 4127      1.0       1   16M      10+  Paid  $2.99       Everyone
# 5151      1.0       1   28M      50+  Free      0       Everyone
# 5978      1.0       1  2.0M      50+  Paid  $1.49       Everyone
# 6008      1.4      45   13M   5,000+  Free      0       Everyone
# 6319      1.0       1  4.9M   1,000+  Free      0       Everyone
# 6490      1.0       1  2.3M     100+  Free      0       Everyone
# 7126      1.5      57   25M   1,000+  Free      0       Everyone
# 7144      1.0       3  8.4M     500+  Free      0       Everyone
# 7254      1.5       2  3.0M     100+  Free      0       Everyone
# 7383      1.0       1  6.6M     100+  Free      0       Everyone
# 7427      1.0       5   13M     100+  Free      0       Everyone
# 7677      1.4      20  4.1M   1,000+  Free      0       Everyone
# 7806      1.0       1  7.8M     100+  Free      0       Everyone
# 7926      1.0       2  7.2M   1,000+  Free      0       Everyone
# 8258      1.4      33  3.1M   1,000+  Free      0       Everyone
# 8820      1.0       2  4.4M     500+  Free      0       Everyone
# 8875      1.0       1   24M      50+  Free      0       Everyone
# 10082     1.2      44   27M   1,000+  Free      0       Everyone
# 10324     1.0       2   21M   1,000+  Free      0       Everyone
# 10400     1.0       2   33M     100+  Free      0       Everyone
# 10562     1.5       2   26M       5+  Free      0       Everyone
# 10591     1.0       3   41M     500+  Free      0       Everyone
#
#                  Genres        Last Updated   Current Ver   Android Ver
# 625              Dating       July 31, 2018          3.52  4.0.3 and up
# 4127          Education     October 7, 2016           1.0  2.3.3 and up
# 5151            Medical         May 1, 2017   300000.0.81  4.0.3 and up
# 5978          Education       April 9, 2012           1.0    2.1 and up
# 6008   Health & Fitness  September 12, 2016           1.0    4.1 and up
# 6319               Card        May 21, 2018      6.2-sayc    4.0 and up
# 6490            Medical   December 14, 2016         1.1.3    4.3 and up
# 7126            Finance   February 26, 2018         4.3.6    4.2 and up
# 7144            Finance   February 22, 2016      4.4.1255    4.0 and up
# 7254          Lifestyle        June 7, 2018       3.9.9.2    2.3 and up
# 7383       Productivity      March 15, 2018          41.9    4.1 and up
# 7427      Communication     October 6, 2017           1.0    4.1 and up
# 7677              Tools        July 6, 2018         2.1.5    4.3 and up
# 7806           Business       July 23, 2014         2.4.2  2.3.3 and up
# 7926            Finance       July 25, 2017         1.0.1    4.0 and up
# 8258             Trivia   December 25, 2017          1.10    4.1 and up
# 8820              Tools      March 23, 2018  2.0.180226.1    4.0 and up
# 8875              Tools      March 27, 2018           3.1    2.2 and up
# 10082           Finance       April 9, 2018        3.24.0    6.0 and up
# 10324         Education       July 27, 2018     5.33.3669    5.0 and up
# 10400           Medical        July 2, 2018         2.0.1    4.1 and up
# 10562            Sports   February 21, 2018           1.0    4.1 and up
# 10591             Tools   December 12, 2017           1.0    4.2 and up

# %%
good_apps=apps[apps['Rating']>=4]
good_apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# 5         4.4     167                5.6M      50,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10834     4.0       7                2.6M         500+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                   Genres      Last Updated  \
# 0           Everyone             Art & Design   January 7, 2018
# 2           Everyone             Art & Design    August 1, 2018
# 3               Teen             Art & Design      June 8, 2018
# 4           Everyone  Art & Design;Creativity     June 20, 2018
# 5           Everyone             Art & Design    March 26, 2017
# ...              ...                      ...               ...
# 10834       Everyone                Education     June 18, 2017
# 10836       Everyone                Education     July 25, 2017
# 10837       Everyone                Education      July 6, 2018
# 10839     Mature 17+        Books & Reference  January 19, 2015
# 10840       Everyone                Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# 5                     1.0          2.3 and up
# ...                   ...                 ...
# 10834               1.0.0          4.1 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [7369 rows x 13 columns]

# %% [markdown]
# **Question 4.3.** How many apps listed have the word "Google" (with that exact capitalization) in the App name? Save the number as `google_apps`.
#
# Note: each row is a separate App and should be counted as such (even if the names are the same).

# %%
#your code here
google_apps = apps[apps['App'].apply(lambda x: True if 'Google' in x else False)]
google_apps
# Out:
#                                  App             Category  Rating  Reviews  \
# 152                Google Play Books  BOOKS_AND_REFERENCE     3.9  1433233
# 193               Google My Business             BUSINESS     4.4    70991
# 198                    Google Primer             BUSINESS     4.4    62272
# 238                       Google Ads             BUSINESS     4.3    29313
# 239               Google My Business             BUSINESS     4.4    70991
# ...                              ...                  ...     ...      ...
# 8636                     Google Keep         PRODUCTIVITY     4.4   691474
# 8659  Cal - Google Calendar + Widget         PRODUCTIVITY     4.2    86172
# 9838           Google Arts & Culture               FAMILY     3.7    24137
# 9841                    Google Earth     TRAVEL_AND_LOCAL     4.3  2339098
# 9844                     Google News   NEWS_AND_MAGAZINES     3.9   878065
#
#                     Size        Installs  Type Price Content Rating  \
# 152   Varies with device  1,000,000,000+  Free     0           Teen
# 193   Varies with device      5,000,000+  Free     0       Everyone
# 198                  18M     10,000,000+  Free     0       Everyone
# 238                  20M      5,000,000+  Free     0       Everyone
# 239   Varies with device      5,000,000+  Free     0       Everyone
# ...                  ...             ...   ...   ...            ...
# 8636  Varies with device    100,000,000+  Free     0       Everyone
# 8659                 13M      1,000,000+  Free     0       Everyone
# 9838  Varies with device      5,000,000+  Free     0       Everyone
# 9841  Varies with device    100,000,000+  Free     0       Everyone
# 9844                 13M  1,000,000,000+  Free     0           Teen
#
#                  Genres      Last Updated         Current Ver  \
# 152   Books & Reference    August 3, 2018  Varies with device
# 193            Business     July 24, 2018    2.19.0.204537701
# 198            Business     June 26, 2018             3.550.2
# 238            Business     July 30, 2018              1.12.0
# 239            Business     July 24, 2018    2.19.0.204537701
# ...                 ...               ...                 ...
# 8636       Productivity    August 6, 2018  Varies with device
# 8659       Productivity  February 1, 2016               1.1.7
# 9838          Education     June 25, 2018  Varies with device
# 9841     Travel & Local     June 18, 2018           9.2.17.13
# 9844   News & Magazines    August 1, 2018               5.2.0
#
#              Android Ver
# 152   Varies with device
# 193           4.4 and up
# 198           4.1 and up
# 238         4.0.3 and up
# 239           4.4 and up
# ...                  ...
# 8636  Varies with device
# 8659          4.0 and up
# 9838  Varies with device
# 9841          4.1 and up
# 9844          4.4 and up
#
# [94 rows x 13 columns]

# %% [markdown]
# **Question 4.4.** Of the apps under the Category `COMMUNICATION`, get the `Content Rating` count for apps where the Rating is between or equal to 4 and 5 (inclusive). Return this as a table sorted by `count` (with greatest count at the top of the table) called `top_communication_apps`.
#
# Hint: creating two Dataframes may help. Even though it is possible to do this in one line, sometimes it's better to break up the tasks to make the overall process clearer. We will only check the final table though.

# %%
#your code here
top_communication_apps = apps.groupby('Category').get_group('COMMUNICATION')
top_communication_apps = top_communication_apps[top_communication_apps['Rating']>=4.0]
top_communication_apps.sort_values(by='Rating',ascending =False)
# Out:
#                                            App       Category  Rating  \
# 7142                                Cb browser  COMMUNICATION     5.0
# 9455                              EJ messenger  COMMUNICATION     5.0
# 6852                                        BV  COMMUNICATION     5.0
# 9119                                   chat dz  COMMUNICATION     5.0
# 6727                                 BS-Mobile  COMMUNICATION     5.0
# ...                                        ...            ...     ...
# 4153                                  Hangouts  COMMUNICATION     4.0
# 8750                  Call Blocker & Blacklist  COMMUNICATION     4.0
# 4754                                 X Browser  COMMUNICATION     4.0
# 8497                                DK Browser  COMMUNICATION     4.0
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
#
#        Reviews                Size        Installs  Type Price Content Rating  \
# 7142         5                3.7M             50+  Free     0       Everyone
# 9455         1                 25M             10+  Free     0           Teen
# 6852         3                1.6M            100+  Free     0       Everyone
# 9119         8                 29M            100+  Free     0           Teen
# 6727         1                683k             50+  Free     0       Everyone
# ...        ...                 ...             ...   ...   ...            ...
# 4153   3419464  Varies with device  1,000,000,000+  Free     0       Everyone
# 8750         6                4.2M          1,000+  Free     0       Everyone
# 4754       142                2.5M         50,000+  Free     0       Everyone
# 8497         1                2.4M             10+  Free     0       Everyone
# 335   56642847  Varies with device  1,000,000,000+  Free     0       Everyone
#
#              Genres       Last Updated         Current Ver         Android Ver
# 7142  Communication      April 2, 2018                 1.0          4.0 and up
# 9455  Communication   October 18, 2017                 1.0          4.0 and up
# 6852  Communication     August 4, 2016                1,01          3.0 and up
# 9119  Communication     March 14, 2018                 1.0          4.1 and up
# 6727  Communication  September 3, 2015                 0.1          2.3 and up
# ...             ...                ...                 ...                 ...
# 4153  Communication      July 21, 2018  Varies with device  Varies with device
# 8750  Communication      July 13, 2018               3.1.0          4.0 and up
# 4754  Communication  December 31, 2017               1.1.1          4.0 and up
# 8497  Communication     April 25, 2017                 1.0          4.2 and up
# 335   Communication     August 1, 2018  Varies with device  Varies with device
#
# [268 rows x 13 columns]

# %% [markdown]
# **Question 4.5.** Create a table named `install_stats` which has a single column, `Installs`, which contains the mean number of install of apps in each type of content rating.

# %%
#your code here
#Removing row with garbage
apps = apps[apps.Installs != 'Free']
#converting install string into an int 
def cleaner(x):
    y = (x.replace(',',''))
    z = int(y.replace('+',''))
    return z

install_stats = pd.DataFrame()
apps['Installs'] = apps['Installs'].apply(cleaner)
#creating table 'install stats'
install_stats['Installs'] = apps.groupby('Content Rating')['Installs'].mean()
install_stats
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#                      Installs
# Content Rating
# Adults only 18+  6.666667e+05
# Everyone         1.310037e+07
# Everyone 10+     3.196590e+07
# Mature 17+       1.107112e+07
# Teen             2.873870e+07
# Unrated          2.525000e+04

# %% [markdown]
# **Question4.6.** Suppose a good app is one with at least one million installs and a rating of at least 4.0. Create a variable called `best_category` containing the name of the category with the most good apps.

# %%
#your code here
good_apps = apps[(apps['Installs']>=1000000) & (apps['Rating']>= 4)]
nice = good_apps.groupby('Category').count()
now = nice[nice['App']==nice['App'].max()].index
now
# Out:
# Index(['GAME'], dtype='object', name='Category')

# %% [markdown]
# **Question 4.7.** Make a bar chart of the average rating by category in which the bars are sorted from smallest to largest.

# %%
#your code here
apps_grouped = apps.groupby('Category')

apps_grouped1=apps_grouped['Rating'].mean()
ap = pd.DataFrame(apps_grouped1.sort_values())
plt.bar(ap.index,ap.Rating)
plt.xticks(rotation='vertical')
plt.xlabel("Categories")
plt.ylabel('Ratings')
plt.show()

# %% [markdown]
# ## 5. Histograms
# Earlier, we computed the average pay among the CEOs in our 102-CEO dataset.  The average doesn't tell us everything about the amounts CEOs are paid, though.  Maybe just a few CEOs make the bulk of the money, even among these 102.

# %% [markdown]
# **Question 5.1.** Make a histogram of the pay of the CEOs in compensation

# %%
#your code Here
plt.hist(raw_compensation['Total_Pay_Dollars'])
plt.xlabel('CEO\'s')
plt.ylabel('compensation')
plt.show()

# %% [markdown]
# **Question 5.2.** Looking at the histogram, about how many CEOs made more than $30 million? Make a good guess. (Answer the question by filling in your answer manually. You'll have to do a bit of arithmetic; feel free to use Python as a calculator.)

# %%
#your code here
num_ceos_more_than_30_million = 10-5

# %% [markdown]
# **Question 5.3.** Answer the same question with code.

# %%
#your code here

def finding_ceos():
    ceo = 0
    for i in raw_compensation['Total_Pay_Dollars']:
        if i>=30:
            ceo=ceo+1
    return ceo    
num_ceos_more_than_30_million_2 = finding_ceos()
num_ceos_more_than_30_million_2
# Out:
# 5

# %% [markdown]
# Run the next cell if you want to see how far off you were.

# %%
percent_diff = abs(num_ceos_more_than_30_million - num_ceos_more_than_30_million_2) / num_ceos_more_than_30_million_2
print("Your guess was only", percent_diff * 100, "% off!")
# Out:
# Your guess was only 0.0 % off!

# %% [markdown]
# ### Finish Line
